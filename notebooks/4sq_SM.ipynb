# %% [markdown]
# # 4sq

# %%
import getpass

import requests
import json
import pandas as pd

# %% [markdown]
# fsq3IBz8M5CTm58GImdCWcCYGDNh5OmA6s8Ue4/YPN7SNe8=

# %% [markdown]
# ## Token

# %%
token = getpass.getpass(prompt='Enter your token: ')
# Out:
# Enter your token: ········

# %% [markdown]
# ## SANTA MONICA

# %%
santa_monica = ["34.019858", "-118.492769"]  # LAT / LON

# %% [markdown]
# ###### category

# %%
def query_from_frousquare_category (lon, lat, radius, category, limit):

    url = f"https://api.foursquare.com/v3/places/search?ll={lon}%2C{lat}&radius={radius}&categories={category}&sort=DISTANCE&limit={limit}"
    headers = {
        "accept": "application/json",
        "Authorization": token
    }

    response = requests.get(url, headers=headers)
    
    return response

# %% [markdown]
# ###### query

# %%
def query_from_frousquare (query, lon, lat, radius, limit):
    
    url = f"https://api.foursquare.com/v3/places/search?query={query}&ll={lon}%2C{lat}&radius={radius}&sort=DISTANCE&limit={limit}"

    headers = {
        "accept": "application/json",
        "Authorization": token
    }

    response = requests.get(url, headers=headers)
    
    return response

# %% [markdown]
# ###### df

# %%
def something_near_somewhere (element):
    
    name = element["name"]
    address = element["location"]["formatted_address"]
    lat = element["geocodes"]["main"]["latitude"]
    lon = element["geocodes"]["main"]["longitude"]
    category_id = element["categories"][0]["id"]
    category = element["categories"][0]["name"]

    dict_ = {"name": name, "address":address, "lat": lat, "lon": lon, "category_id" : category_id, "category": category}
    
    return dict_

# %% [markdown]
# ### Preschool

# %%
response = query_from_frousquare_category (santa_monica[0], santa_monica[1], 5000, 12056, 5)
response = response.json()

# %%
new_lst_1 = []

for i in response["results"]:
    new_lst_1.append(something_near_somewhere(i))

# %%
df1 = pd.DataFrame(new_lst_1)
df1
# Out:
#                          name
# 0             Piper Preschool  \
# 1        Gan Israel Preschool
# 2       10th Street Preschool
# 3          Knowledge Universe
# 4  KinderCare Learning Center
#
#                                              address        lat         lon
# 0  807 Arizona Ave (Arizona), Santa Monica, CA 90401  34.021219 -118.492906  \
# 1  1341 9th St (Santa Monica Blvd), Santa Monica,...  34.020859 -118.490709
# 2               1444 10th St, Santa Monica, CA 90401  34.019880 -118.488781
# 3                1250 4th St, Santa Monica, CA 90401  34.017819 -118.497217
# 4                1250 4th St, Santa Monica, CA 90401  34.017751 -118.497215
#
#    category_id            category
# 0        12056           Preschool
# 1        11025  Child Care Service
# 2        11025  Child Care Service
# 3        11025  Child Care Service
# 4        12056           Preschool

# %% [markdown]
# ### Elementary school

# %%
response = query_from_frousquare_category (santa_monica[0], santa_monica[1], 5000,12057 , 5)
response = response.json()

# %%
new_lst_2 = []

for i in response["results"]:
    new_lst_2.append(something_near_somewhere(i))

# %%
df2 = pd.DataFrame(new_lst_2)
df2
# Out:
#                                     name
# 0              Sycamore Community School  \
# 1  Watts Kenneth PhD Educational Therapy
# 2                                   Ps#1
# 3         St Monica Catholic High School
# 4              P S # 1 Elementary School
#
#                                      address        lat         lon
# 0        1229 4th St, Santa Monica, CA 90401  34.018463 -118.497159  \
# 1        1535 6th St, Santa Monica, CA 90401  34.015931 -118.490466
# 2       1447 12th St, Santa Monica, CA 90401  34.021733 -118.486134
# 3  1030 Lincoln Blvd, Santa Monica, CA 90403  34.024076 -118.497134
# 4     1454 Euclid St, Santa Monica, CA 90404  34.021992 -118.485503
#
#    category_id           category
# 0        12058  Elementary School
# 1        12058  Elementary School
# 2        12058  Elementary School
# 3        12059        High School
# 4        12058  Elementary School

# %% [markdown]
# ### High school

# %%
response = query_from_frousquare_category (santa_monica[0], santa_monica[1], 10000,12059 , 5)
response = response.json()

# %%
new_lst_3 = []

for i in response["results"]:
    new_lst_3.append(something_near_somewhere(i))

# %%
df3 = pd.DataFrame(new_lst_3)
df3
# Out:
#                              name
# 0  St Monica Catholic High School  \
# 1        Santa Monica High School
# 2  Pacifica Christian High School
# 3             Olympic High School
# 4               Writers Boot Camp
#
#                                              address        lat         lon
# 0          1030 Lincoln Blvd, Santa Monica, CA 90403  34.024076 -118.497134  \
# 1     601 Pico Blvd (6th St), Santa Monica, CA 90405  34.011357 -118.485073
# 2         1730 Wilshire Blvd, Santa Monica, CA 90403  34.029315 -118.484947
# 3               2425 16th St, Santa Monica, CA 90405  34.013482 -118.469148
# 4  2519 Michigan Ave (26th St), Santa Monica, CA ...  34.027339 -118.468371
#
#    category_id     category
# 0        12059  High School
# 1        12059  High School
# 2        12059  High School
# 3        12059  High School
# 4        12059  High School

# %% [markdown]
# ### Playground park

# %%
response = query_from_frousquare_category (santa_monica[0], santa_monica[1], 10000,16037 , 5)
response = response.json()

# %%
new_lst_4 = []

for i in response["results"]:
    new_lst_4.append(something_near_somewhere(i))

# %%
df4 = pd.DataFrame(new_lst_4)
df4
# Out:
#                           name
# 0  Christine Emerson Reed Park  \
# 1         Playground Reed Park
# 2             Samo's Clubhouse
# 3                  Euclid Park
# 4       Swings At Santa Monica
#
#                                              address        lat         lon
# 0     1133 7th St (Wilshire), Santa Monica, CA 90403  34.022604 -118.495761  \
# 1                             Santa Monica, CA 90403  34.022386 -118.496181
# 2       395 Santa Monica Blvd, Los Angeles, CA 90401  34.013330 -118.494157
# 3  1525 Euclid St (Broadway), Santa Monica, CA 90404  34.021700 -118.484225
# 4             1500 Ocean Ave, Santa Monica, CA 90401  34.012469 -118.495552
#
#    category_id     category
# 0        16036  Picnic Area
# 1        16037   Playground
# 2        16037   Playground
# 3        16037   Playground
# 4        16037   Playground

# %% [markdown]
# ### Airports

# %%
response = query_from_frousquare_category (santa_monica[0], santa_monica[1], 15000, 19040 , 10)
response = response.json()

# %%
new_lst_5 = []

for i in response["results"]:
    new_lst_5.append(something_near_somewhere(i))

# %%
df5 = pd.DataFrame(new_lst_5)
df5
# Out:
#                                       name
# 0  Los Angeles International Airport (LAX)  \
#
#                               address        lat         lon  category_id
# 0  1 World Way, Los Angeles, CA 90045  33.944697 -118.398107        19040  \
#
#                 category
# 0  International Airport

# %% [markdown]
# ### Train stations

# %%
response = query_from_frousquare_category (santa_monica[0], santa_monica[1], 15000, 19047 , 5)
response = response.json()

# %%
new_lst_6 = []

for i in response["results"]:
    new_lst_6.append(something_near_somewhere(i))

# %%
df6 = pd.DataFrame(new_lst_6)
df6
# Out:
#                                     name
# 0  Metro - Downtown Santa Monica Station  \
# 1              17th Street / SMC Station
# 2                   26th Street/Bergamot
# 3                    Metro Expo Facility
# 4                           Robert Sasan
#
#                                              address        lat         lon
# 0  401 Colorado Ave (at 4th St), Santa Monica, CA...  34.013832 -118.491482  \
# 1          1610 Colorado Ave, Santa Monica, CA 90404  34.023167 -118.480087
# 2           Olympic Boulevard, Los Angeles, CA 90404  34.027953 -118.469161
# 3                             Santa Monica, CA 90404  34.029282 -118.462262
# 4             11950 Idaho Ave, Los Angeles, CA 90025  34.039305 -118.459922
#
#    category_id      category
# 0        19047  Rail Station
# 1        19047  Rail Station
# 2        19047  Rail Station
# 3        19047  Rail Station
# 4        19047  Rail Station

# %% [markdown]
# ### Vegan restaurants

# %%
response = query_from_frousquare ("vegan", santa_monica[0], santa_monica[1], 10000, 10)
response = response.json()

# %%
new_lst_8 = []

for i in response["results"]:
    new_lst_8.append(something_near_somewhere(i))

# %%
df8 = pd.DataFrame(new_lst_8)
df8
# Out:
#                             name
# 0                  Sweetfin Poké  \
# 1                 Superfood Cafe
# 2                       The Hive
# 3                     Sweetgreen
# 4                    Huckleberry
# 5    The Misfit Bar & Restaurant
# 6                  Tender Greens
# 7                   Simply Salad
# 8                   Flower Child
# 9  800 Degrees Woodfired Kitchen
#
#                                              address        lat         lon
# 0  829 Broadway (at Lincoln Ct), Santa Monica, CA...  34.018810 -118.489395  \
# 1  530 Wilshire Blvd (at 6th St.), Santa Monica, ...  34.020219 -118.496277
# 2         606 Broadway (6th), Santa Monica, CA 90401  34.016748 -118.491260
# 3                1343 4th St, Santa Monica, CA 90401  34.017037 -118.495434
# 4  1014 Wilshire Blvd (at 10th Ct), Santa Monica,...  34.023849 -118.492183
# 5  225 Santa Monica Blvd (at 2nd St), Santa Monic...  34.015578 -118.496534
# 6  201 Arizona Ave (at 2nd St), Santa Monica, CA ...  34.016520 -118.498532
# 7                1401 2nd St, Santa Monica, CA 90401  34.014892 -118.496803
# 8                1332 2nd St, Santa Monica, CA 90401  34.015288 -118.498012
# 9          120 Wilshire Blvd, Santa Monica, CA 90401  34.017270 -118.500243
#
#    category_id                         category
# 0        13065                       Restaurant
# 1        13377  Vegan and Vegetarian Restaurant
# 2        13000              Dining and Drinking
# 3        13065                       Restaurant
# 4        13002                           Bakery
# 5        13065                       Restaurant
# 6        13068              American Restaurant
# 7        13145             Fast Food Restaurant
# 8        13068              American Restaurant
# 9        13064                         Pizzeria

# %% [markdown]
# ### Pubs

# %%
response = query_from_frousquare_category (santa_monica[0], santa_monica[1], 5000, 13018 , 5)
response = response.json()

# %%
new_lst_9 = []

for i in response["results"]:
    new_lst_9.append(something_near_somewhere(i))

# %%
df9 = pd.DataFrame(new_lst_9)
df9
# Out:
#                                name
# 0  Santa Monica Beer Scavenger Hunt  \
# 1                     Jameson's Pub
# 2                    Sonny McLean's
# 3                       Eat Berlins
#
#                                              address        lat         lon
# 0      3RD St (Santa Monica), Santa Monica, CA 90401  34.011132 -118.488530  \
# 1  2702 Main St (at Hill St), Santa Monica, CA 90405  34.000724 -118.482664
# 2         2615 Wilshire Blvd, Santa Monica, CA 90403  34.036589 -118.477253
# 3            1425 Ocean Front Walk, Venice, CA 90291  33.987740 -118.474133
#
#    category_id   category
# 0        13018        Pub
# 1        13017  Piano Bar
# 2        13018        Pub
# 3        13018        Pub

# %% [markdown]
# ### Night club

# %%
response = query_from_frousquare_category (santa_monica[0], santa_monica[1], 15000, 10032 , 5)
response = response.json()

# %%
new_lst_10 = []

for i in response["results"]:
    new_lst_10.append(something_near_somewhere(i))

# %%
df10 = pd.DataFrame(new_lst_10)
df10
# Out:
#                    name                                            address
# 0  Harvelles Blues Club  1432 4th St (btw Santa Monica Blvd & Broadway)...  \
# 1  German American Club          1843 Lincoln Blvd, Santa Monica, CA 90404
# 2         Senator Jones  2020 Wilshire Blvd (btwn 20th & 21st St), Sant...
# 3          Zugell Zumba               2523 17th St, Santa Monica, CA 90405
# 4          Busby's West  3110 Santa Monica Blvd (at Berkeley Ave.), San...
#
#          lat         lon  category_id    category
# 0  34.015618 -118.494486        10032  Night Club
# 1  34.013206 -118.483486        10032  Night Club
# 2  34.031641 -118.482310        10032  Night Club
# 3  34.013111 -118.467233        10032  Night Club
# 4  34.037184 -118.469137        10032  Night Club

# %% [markdown]
# ### Pet Grooming Service

# %%
response = query_from_frousquare_category (santa_monica[0], santa_monica[1], 5000, 11134 , 5)
response = response.json()

# %%
new_lst_11 = []

for i in response["results"]:
    new_lst_11.append(something_near_somewhere(i))

# %%
df11 = pd.DataFrame(new_lst_11)
df11
# Out:
#                     name                                            address
# 0           Healthy Spot  1110 Wilshire Blvd (at 11th St), Santa Monica,...  \
# 1  Moon Doggy's Dog Wash          1838 Lincoln Blvd, Santa Monica, CA 90404
# 2             To Wag For    1123 Montana Ave (10th), Santa Monica, CA 90403
# 3       The Wagging Tail           1123 Montana Ave, Santa Monica, CA 90403
# 4     Yo Dawg Groom Spot  1844 14th St (Pico Blvd.), Santa Monica, CA 90404
#
#          lat         lon  category_id              category
# 0  34.024581 -118.491231        11134  Pet Grooming Service
# 1  34.012915 -118.484045        11134  Pet Grooming Service
# 2  34.030589 -118.497481        11134  Pet Grooming Service
# 3  34.030553 -118.497551        11134  Pet Grooming Service
# 4  34.017209 -118.478410        11134  Pet Grooming Service

# %% [markdown]
# ### Dog parks

# %%
response = query_from_frousquare_category (santa_monica[0], santa_monica[1], 5000, 16033 , 5)
response = response.json()

# %%
new_lst_12 = []

for i in response["results"]:
    new_lst_12.append(something_near_somewhere(i))

# %%
df12 = pd.DataFrame(new_lst_12)
df12
# Out:
#                                      name
# 0  DOG PPL - Dog Park, Bar, Cafe & Lounge  \
# 1   Beneful's Virtual Dog Park Storescape
# 2                                Dog Town
# 3                   Memorial Park Dog Run
# 4                         Secret Dog Park
#
#                                              address        lat         lon
# 0                             Santa Monica, CA 90401  34.017297 -118.494804  \
# 1  395 Santa Monica Pl (in Santa Monica Place), S...  34.013704 -118.494094
# 2                             Santa Monica, CA 90401  34.011070 -118.494958
# 3  1621 14th St (at Colorado Ave.), Santa Monica,...  34.021248 -118.481728
# 4                    Stanley, Santa Monica, CA 90404  34.032122 -118.468893
#
#    category_id  category
# 0        16033  Dog Park
# 1        16033  Dog Park
# 2        16033  Dog Park
# 3        16033  Dog Park
# 4        16033  Dog Park

# %% [markdown]
# ### Starbucks

# %%
response = query_from_frousquare ("starbucks", santa_monica[0], santa_monica[1], 5000, 5)
response = response.json()

# %%
new_lst_13 = []

for i in response["results"]:
    new_lst_13.append(something_near_somewhere(i))

# %%
df13 = pd.DataFrame(new_lst_13)
df13
# Out:
#         name                                            address        lat
# 0  Starbucks               710 Broadway, Santa Monica, CA 90401  34.017199  \
# 1  Starbucks  1030 Wilshire Blvd (11th), Santa Monica, CA 90401  34.024139
# 2  Starbucks  1356 3rd Street Promenade, Santa Monica, CA 90401  34.015744
# 3  Starbucks         1311 Wilshire Blvd, Santa Monica, CA 90403  34.026503
# 4  Starbucks  1705 Ocean Ave (Civic Center Dr.), Santa Monic...  34.010651
#
#           lon  category_id     category
# 0 -118.489997        13035  Coffee Shop
# 1 -118.491624        13035  Coffee Shop
# 2 -118.496609        13035  Coffee Shop
# 3 -118.489836        13035  Coffee Shop
# 4 -118.491558        13035  Coffee Shop

# %% [markdown]
# ### Basketball

# %%
response = query_from_frousquare_category (santa_monica[0], santa_monica[1], 10000, 18006 , 5)
response = response.json()

# %%
new_lst_14 = []

for i in response["results"]:
    new_lst_14.append(something_near_somewhere(i))

# %%
df14 = pd.DataFrame(new_lst_14)
df14
# Out:
#                               name
# 0  Memorial Park Basketball Courts  \
# 1                Basketball Courts
# 2   Venice Beach Basketball Courts
# 3                 Mar Vista Courts
# 4                     Saxon Courts
#
#                                              address        lat         lon
# 0  1401 Olympic Blvd (14th and Olympic), Santa Mo...  34.019934 -118.480656  \
# 1  1406 Marine St (at 16th St.), Santa Monica, CA...  34.006221 -118.465114
# 2  1800 Ocean Front Walk (at 18th Pl), Venice, CA...  33.986028 -118.472826
# 3           11430 Woodbine St, Los Angeles, CA 90066  34.017965 -118.428676
# 4              250 De Neve Dr, Los Angeles, CA 90024  34.071410 -118.452657
#
#    category_id          category
# 0        18008  Basketball Court
# 1        18008  Basketball Court
# 2        18008  Basketball Court
# 3        18008  Basketball Court
# 4        18008  Basketball Court

# %% [markdown]
# ### Design

# %%
response = query_from_frousquare_category (santa_monica[0], santa_monica[1], 15000, 11030 , 5)
response = response.json()

# %%
new_lst_15 = []

for i in response["results"]:
    new_lst_15.append(something_near_somewhere(i))

# %%
df15 = pd.DataFrame(new_lst_15)
df15
# Out:
#                           name
# 0                   SLS Ad Co.  \
# 1  First Contact Entertainment
# 2            Thought Merchants
# 3                Active Theory
# 4                     Photowow
#
#                                              address        lat         lon
# 0  1453 3rd Street Promenade (btwn Broadway & San...  34.014770 -118.494540  \
# 1                1333 2nd St, Santa Monica, CA 90401  34.015714 -118.497456
# 2  216 Pico Blvd (Main Street), Santa Monica, CA ...  34.008138 -118.489033
# 3     615 Hampton Dr (Sunset Blvd), Venice, CA 90291  33.994390 -118.475399
# 4  11950 Wilshire Blvd (Brockton), Los Angeles, C...  34.045646 -118.465069
#
#    category_id       category
# 0        11030  Design Studio
# 1        11030  Design Studio
# 2        11030  Design Studio
# 3        11030  Design Studio
# 4        11030  Design Studio

# %% [markdown]
# # CONCATENATE

# %%
df_santa_monica = pd.concat([df1, 
                              df2, 
                              df3, 
                              df4, 
                              df5, 
                              df6, 
                              df7, 
                              df9, 
                              df10, 
                              df11, 
                              df12, 
                              df13, 
                              df14, 
                              df15])

# %%
df_santa_monica = df_santa_monica.reset_index(drop=True)

# %%
df_santa_monica
# Out:
#                            name
# 0               Piper Preschool  \
# 1          Gan Israel Preschool
# 2         10th Street Preschool
# 3            Knowledge Universe
# 4    KinderCare Learning Center
# ..                          ...
# 65                   SLS Ad Co.
# 66  First Contact Entertainment
# 67            Thought Merchants
# 68                Active Theory
# 69                     Photowow
#
#                                               address        lat         lon
# 0   807 Arizona Ave (Arizona), Santa Monica, CA 90401  34.021219 -118.492906  \
# 1   1341 9th St (Santa Monica Blvd), Santa Monica,...  34.020859 -118.490709
# 2                1444 10th St, Santa Monica, CA 90401  34.019880 -118.488781
# 3                 1250 4th St, Santa Monica, CA 90401  34.017819 -118.497217
# 4                 1250 4th St, Santa Monica, CA 90401  34.017751 -118.497215
# ..                                                ...        ...         ...
# 65  1453 3rd Street Promenade (btwn Broadway & San...  34.014770 -118.494540
# 66                1333 2nd St, Santa Monica, CA 90401  34.015714 -118.497456
# 67  216 Pico Blvd (Main Street), Santa Monica, CA ...  34.008138 -118.489033
# 68     615 Hampton Dr (Sunset Blvd), Venice, CA 90291  33.994390 -118.475399
# 69  11950 Wilshire Blvd (Brockton), Los Angeles, C...  34.045646 -118.465069
#
#     category_id            category
# 0         12056           Preschool
# 1         11025  Child Care Service
# 2         11025  Child Care Service
# 3         11025  Child Care Service
# 4         12056           Preschool
# ..          ...                 ...
# 65        11030       Design Studio
# 66        11030       Design Studio
# 67        11030       Design Studio
# 68        11030       Design Studio
# 69        11030       Design Studio
#
# [70 rows x 6 columns]

# %% [markdown]
# # SAVE DF

# %%
#df_santa_monica.to_csv("../data/santa_monica.csv", index=False)
